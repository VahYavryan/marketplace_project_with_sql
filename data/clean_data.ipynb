# %%
import pandas as pd

df = pd.read_csv("marketplace.csv")
df.to_csv("marketplace_clean.csv", index=False)

# %%
df = pd.read_csv("marketplace.csv", index_col=0)
df.to_csv("marketplace_clean.csv", index=False)
